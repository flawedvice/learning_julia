# %% [markdown]
# # Data Analysis and Further Exploration!
# Here I'll focus on analysis and exploration of the data. Our main goal is to build a Machine Learning model from scratch to predict the price of a new automobile.
#
# To do so, I'll need a deeper understanding of the data at hand.

# %%
using Pkg; Pkg.add("CategoricalArrays")
using CategoricalArrays
using CSV
using DataFrames
using StatsPlots
using CairoMakie
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
df = CSV.read("clean_data.csv", DataFrame)
# Out:
# 159×26 DataFrame
#  Row │ symboling  normalized-losses  make        fuel-type  aspiration  num-of ⋯
#      │ Int64      Int64              String15    String7    String7     String ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         2                164  audi        gas        std         four   ⋯
#    2 │         2                164  audi        gas        std         four
#    3 │         1                158  audi        gas        std         four
#    4 │         1                158  audi        gas        turbo       four
#    5 │         2                192  bmw         gas        std         two    ⋯
#    6 │         0                192  bmw         gas        std         four
#    7 │         0                188  bmw         gas        std         two
#    8 │         0                188  bmw         gas        std         four
#    9 │         2                121  chevrolet   gas        std         two    ⋯
#   10 │         1                 98  chevrolet   gas        std         two
#   11 │         0                 81  chevrolet   gas        std         four
#   ⋮  │     ⋮              ⋮              ⋮           ⋮          ⋮            ⋮ ⋱
#  150 │        -1                 74  volvo       gas        std         four
#  151 │        -2                103  volvo       gas        std         four   ⋯
#  152 │        -1                 74  volvo       gas        std         four
#  153 │        -2                103  volvo       gas        turbo       four
#  154 │        -1                 74  volvo       gas        turbo       four
#  155 │        -1                 95  volvo       gas        std         four   ⋯
#  156 │        -1                 95  volvo       gas        turbo       four
#  157 │        -1                 95  volvo       gas        std         four
#  158 │        -1                 95  volvo       diesel     turbo       four
#  159 │        -1                 95  volvo       gas        turbo       four   ⋯
#                                                  21 columns and 138 rows omitted

# %% [markdown]
# # Analysing the data
# We can separate our data into Categorical and Numeric.
#
# I think that a good way to start is to create barplots for categorical data against price and correlation matrices for numeric data in order to understand it better.
#
# I'll take just a subset of the whole Dataset for this purpose.

# %%
using Random

qty = Int(round(nrow(df)*0.6))

selectedrows = shuffle(1:nrow(df))[1:qty]

sample_set = df[selectedrows, :]
# Out:
# 95×26 DataFrame
#  Row │ symboling  normalized-losses  make           fuel-type  aspiration  num ⋯
#      │ Int64      Int64              String15       String7    String7     Str ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         1                154  plymouth       gas        std         fou ⋯
#    2 │         1                107  honda          gas        std         two
#    3 │         3                197  toyota         gas        std         two
#    4 │        -1                137  mitsubishi     gas        std         fou
#    5 │         3                153  mitsubishi     gas        std         two ⋯
#    6 │        -1                 93  mercedes-benz  diesel     turbo       fou
#    7 │         0                118  mazda          gas        std         fou
#    8 │         0                 85  honda          gas        std         fou
#    9 │         1                101  honda          gas        std         two ⋯
#   10 │        -1                 95  volvo          gas        std         fou
#   11 │         0                 85  honda          gas        std         fou
#   ⋮  │     ⋮              ⋮                ⋮            ⋮          ⋮           ⋱
#   86 │         1                168  toyota         gas        std         two
#   87 │         1                119  plymouth       gas        std         two ⋯
#   88 │         1                129  mazda          gas        std         two
#   89 │         0                106  nissan         gas        std         fou
#   90 │         3                150  saab           gas        std         two
#   91 │         0                 91  toyota         gas        std         fou ⋯
#   92 │         0                161  peugot         gas        std         fou
#   93 │         2                134  toyota         gas        std         two
#   94 │         1                148  dodge          gas        std         fou
#   95 │         1                 87  toyota         gas        std         two ⋯
#                                                   21 columns and 74 rows omitted

# %%
cat_cols = ["make", "fuel-type", "aspiration", "num-of-doors",
            "body-style", "drive-wheels", "engine-location",
            "engine-type", "fuel-system", "num-of-cylinders"]

cat_sample = select(sample_set, cat_cols, "price")
num_sample = select(sample_set, Not(cat_cols), "price")
# Out:
# 95×16 DataFrame
#  Row │ symboling  normalized-losses  wheel-base  length   width    height   cu ⋯
#      │ Int64      Int64              Float64     Float64  Float64  Float64  In ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         1                154        93.7    167.3     63.8     50.8     ⋯
#    2 │         1                107        96.5    169.1     66.0     51.0
#    3 │         3                197       102.9    183.5     67.7     52.0
#    4 │        -1                137        96.3    172.4     65.4     51.6
#    5 │         3                153        96.3    173.0     65.4     49.4     ⋯
#    6 │        -1                 93       115.6    202.6     71.7     56.3
#    7 │         0                118       104.9    175.0     66.1     54.4
#    8 │         0                 85        96.5    175.4     65.2     54.1
#    9 │         1                101        93.7    150.0     64.0     52.6     ⋯
#   10 │        -1                 95       109.1    188.8     68.9     55.5
#   11 │         0                 85        96.5    175.4     62.5     54.1
#   ⋮  │     ⋮              ⋮              ⋮          ⋮        ⋮        ⋮        ⋱
#   86 │         1                168        94.5    168.7     64.0     52.6
#   87 │         1                119        93.7    157.3     63.8     50.8     ⋯
#   88 │         1                129        98.8    177.8     66.5     53.7
#   89 │         0                106        97.2    173.4     65.2     54.7
#   90 │         3                150        99.1    186.6     66.5     56.1
#   91 │         0                 91        95.7    166.3     64.4     52.8     ⋯
#   92 │         0                161       107.9    186.7     68.4     56.7
#   93 │         2                134        98.4    176.2     65.6     52.0
#   94 │         1                148        93.7    157.3     63.8     50.6
#   95 │         1                 87        95.7    158.7     63.6     54.5     ⋯
#                                                   10 columns and 74 rows omitted

# %% [markdown]
# ## Categorical Data

# %%
first(cat_sample, 5)
# Out:
# 5×11 DataFrame
#  Row │ make        fuel-type  aspiration  num-of-doors  body-style  drive-whee ⋯
#      │ String15    String7    String7     String7       String15    String3    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ plymouth    gas        std         four          sedan       fwd        ⋯
#    2 │ honda       gas        std         two           sedan       fwd
#    3 │ toyota      gas        std         two           hatchback   rwd
#    4 │ mitsubishi  gas        std         four          sedan       fwd
#    5 │ mitsubishi  gas        std         two           hatchback   fwd        ⋯
#                                                                6 columns omitted

# %% [markdown]
# ### Grouping by Category

# %%
grp_make = groupby(cat_sample, "make")
grp_ftype = groupby(cat_sample, "fuel-type")
grp_asp = groupby(cat_sample, "aspiration")
grp_numd = groupby(cat_sample, "num-of-doors")
grp_bod = groupby(cat_sample, "body-style")
grp_drv = groupby(cat_sample, "drive-wheels")
grp_engloc = groupby(cat_sample, "engine-location")
grp_engtyp = groupby(cat_sample, "engine-type")
grp_fsys = groupby(cat_sample, "fuel-system")
grp_numcyl = groupby(cat_sample, "num-of-cylinders")
# Out:
# GroupedDataFrame with 4 groups based on key: num-of-cylinders
# First Group (83 rows): num-of-cylinders = "four"
#  Row │ make        fuel-type  aspiration  num-of-doors  body-style  drive-whee ⋯
#      │ String15    String7    String7     String7       String15    String3    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ plymouth    gas        std         four          sedan       fwd        ⋯
#    2 │ honda       gas        std         two           sedan       fwd
#    3 │ mitsubishi  gas        std         four          sedan       fwd
#    4 │ mitsubishi  gas        std         two           hatchback   fwd
#    5 │ mazda       gas        std         four          sedan       rwd        ⋯
#    6 │ honda       gas        std         four          sedan       fwd
#    7 │ honda       gas        std         two           hatchback   fwd
#   ⋮  │     ⋮           ⋮          ⋮            ⋮            ⋮            ⋮     ⋱
#   77 │ nissan      gas        std         four          hatchback   fwd
#   78 │ saab        gas        std         two           hatchback   fwd        ⋯
#   79 │ toyota      gas        std         four          sedan       fwd
#   80 │ peugot      gas        std         four          sedan       rwd
#   81 │ toyota      gas        std         two           hardtop     rwd
#   82 │ dodge       gas        std         four          sedan       fwd        ⋯
#   83 │ toyota      gas        std         two           hatchback   fwd
#                                                    6 columns and 69 rows omitted
# ⋮
# Last Group (1 row): num-of-cylinders = "three"
#  Row │ make       fuel-type  aspiration  num-of-doors  body-style  drive-wheel ⋯
#      │ String15   String7    String7     String7       String15    String3     ⋯
#   ⋮  │     ⋮          ⋮          ⋮            ⋮            ⋮            ⋮      ⋱
#                                                      6 columns and 1 row omitted

# %%
using Statistics
plot_data = combine(grp_make, :price => mean)

x = 1:nrow(plot_data)
height = plot_data[:, :price_mean]
labels = plot_data[:, :make]

barplot(x, height, bar_labels=labels)

# %% [markdown]
# So, yeah, there are manufacturers with more expensive cars than others.

# %%
combine(grp_ftype, :price => mean)
# Out:
# 2×2 DataFrame
#  Row │ fuel-type  price_mean
#      │ String7    Float64
# ─────┼───────────────────────
#    1 │ gas           10794.3
#    2 │ diesel        12650.1

# %% [markdown]
# In average, diesel cars cost more... but is this accurate?

# %%
combine(grp_ftype, :price => mean, :price => std, :price => extrema)
# Out:
# 2×4 DataFrame
#  Row │ fuel-type  price_mean  price_std  price_extrema
#      │ String7    Float64     Float64    Tuple…
# ─────┼─────────────────────────────────────────────────
#    1 │ gas           10794.3    5201.34  (5118, 32250)
#    2 │ diesel        12650.1    8585.29  (7775, 31600)

# %% [markdown]
# The price ranges look pretty similar and prices tend to vary a lot. I don't think I'll be taking this feature into consideration.

# %%
droppedfeats = ["fuel-type"]
# Out:
# 1-element Vector{String}:
#  "fuel-type"

# %%
combine(grp_asp, :price => mean, :price => std, :price => extrema)
# Out:
# 2×4 DataFrame
#  Row │ aspiration  price_mean  price_std  price_extrema
#      │ String7     Float64     Float64    Tuple…
# ─────┼──────────────────────────────────────────────────
#    1 │ std            10154.1    4758.91  (5118, 32250)
#    2 │ turbo          15831.7    7200.32  (7689, 31600)

# %% [markdown]
# It's very similar to the fuel-type feature...

# %%
push!(droppedfeats, "aspiration")
# Out:
# 2-element Vector{String}:
#  "fuel-type"
#  "aspiration"

# %%
combine(grp_numd, :price => mean, :price => std, :price => extrema)
# Out:
# 2×4 DataFrame
#  Row │ num-of-doors  price_mean  price_std  price_extrema
#      │ String7       Float64     Float64    Tuple…
# ─────┼────────────────────────────────────────────────────
#    1 │ four            11990.4     5915.87  (6488, 32250)
#    2 │ two              9409.97    4413.87  (5118, 22018)

# %%
push!(droppedfeats, "num-of-doors")
# Out:
# 3-element Vector{String}:
#  "fuel-type"
#  "aspiration"
#  "num-of-doors"

# %%
plot_data = combine(grp_bod, :price => mean, :price => std, :price => extrema)
# Out:
# 4×4 DataFrame
#  Row │ body-style  price_mean  price_std  price_extrema
#      │ String15    Float64     Float64    Tuple…
# ─────┼──────────────────────────────────────────────────
#    1 │ sedan         12610.2     6192.64  (6692, 32250)
#    2 │ hatchback      9047.64    4324.44  (5118, 22018)
#    3 │ wagon          9699.45    3673.48  (6918, 18950)
#    4 │ hardtop        9299.0     1648.48  (8249, 11199)

# %% [markdown]
# Ok, now here we have something more interesting!
# Depending on the body style, the price does change

# %%
x = 1:nrow(plot_data)
height = plot_data[:, "price_mean"]
labels = plot_data[:, "body-style"]

barplot(x, height, bar_labels=labels)

# %% [markdown]
# Great, we have another useful feature then!

# %%
plot_data = combine(grp_drv, :price => mean, :price => std, :price => extrema)
# Out:
# 3×4 DataFrame
#  Row │ drive-wheels  price_mean  price_std  price_extrema
#      │ String3       Float64     Float64    Tuple…
# ─────┼────────────────────────────────────────────────────
#    1 │ fwd              8720.54    3335.11  (5118, 23875)
#    2 │ 4wd              9211.14    1647.85  (7603, 11694)
#    3 │ rwd             16371.1     6253.51  (8058, 32250)

# %%
# Another useful feature!
x = 1:nrow(plot_data)
height = plot_data[:, "price_mean"]
labels = plot_data[:, "drive-wheels"]

barplot(x, height, bar_labels=labels)

# %% [markdown]
# It looks like the Rear-wheel drive cars are quite more expensive than the rest of the cars! Is that right?

# %%
rwd_grp = grp_drv[3]

x= 1:nrow(rwd_grp)
y = rwd_grp[:, :price]
lines(x, y)

# %% [markdown]
# Actually, it looks more like there are some extreme values pushing the mean prices.

# %%
describe(rwd_grp[:, :price])
# Out:
# Summary Stats:
# Length:         27
# Missing Count:  0
# Mean:           16371.148148
# Minimum:        8058.000000
# 1st Quartile:   11724.500000
# Median:         16558.000000
# 3rd Quartile:   18674.500000
# Maximum:        32250.000000
# Type:           Int64

# %%
push!(droppedfeats, "drive-wheels")
# Out:
# 4-element Vector{String}:
#  "fuel-type"
#  "aspiration"
#  "num-of-doors"
#  "drive-wheels"

# %%
combine(grp_engloc, :price => mean, :price => std, :price => extrema)
# Out:
# 1×4 DataFrame
#  Row │ engine-location  price_mean  price_std  price_extrema
#      │ String7          Float64     Float64    Tuple…
# ─────┼───────────────────────────────────────────────────────
#    1 │ front               10931.1    5475.54  (5118, 32250)

# %% [markdown]
# Well, there's only one possible value, so it really won't affect the price of the car (or at least I cannot tell from this dataset).

# %%
push!(droppedfeats, "engine-location")
# Out:
# 5-element Vector{String}:
#  "fuel-type"
#  "aspiration"
#  "num-of-doors"
#  "drive-wheels"
#  "engine-location"

# %%
plot_data = combine(grp_engtyp, :price => mean, :price => std, :price => extrema, :price)
# Out:
# 95×5 DataFrame
#  Row │ engine-type  price_mean  price_std  price_extrema   price
#      │ String7      Float64     Float64    Tuple…          Int64
# ─────┼───────────────────────────────────────────────────────────
#    1 │ ohc             10309.3    5093.77  (5195, 31600)    7609
#    2 │ ohc             10309.3    5093.77  (5195, 31600)   10345
#    3 │ ohc             10309.3    5093.77  (5195, 31600)    9279
#    4 │ ohc             10309.3    5093.77  (5195, 31600)    8499
#    5 │ ohc             10309.3    5093.77  (5195, 31600)   31600
#    6 │ ohc             10309.3    5093.77  (5195, 31600)   18280
#    7 │ ohc             10309.3    5093.77  (5195, 31600)    8845
#    8 │ ohc             10309.3    5093.77  (5195, 31600)    7129
#    9 │ ohc             10309.3    5093.77  (5195, 31600)   16845
#   10 │ ohc             10309.3    5093.77  (5195, 31600)   10295
#   11 │ ohc             10309.3    5093.77  (5195, 31600)    6692
#   ⋮  │      ⋮           ⋮           ⋮            ⋮           ⋮
#   86 │ ohcf             8524.4    2012.33  (5118, 11694)   11694
#   87 │ ohcf             8524.4    2012.33  (5118, 11694)    7126
#   88 │ ohcf             8524.4    2012.33  (5118, 11694)    7775
#   89 │ ohcf             8524.4    2012.33  (5118, 11694)    7603
#   90 │ ohcf             8524.4    2012.33  (5118, 11694)    5118
#   91 │ ohcf             8524.4    2012.33  (5118, 11694)    9960
#   92 │ ohcf             8524.4    2012.33  (5118, 11694)   11259
#   93 │ ohcf             8524.4    2012.33  (5118, 11694)    9233
#   94 │ ohcf             8524.4    2012.33  (5118, 11694)    7463
#   95 │ ohcf             8524.4    2012.33  (5118, 11694)    8013
#                                                   74 rows omitted

# %%
using CategoricalArrays
newcol = categorical(df[:, "engine-type"])

addedcat =  df[:, :]
addedcat[:, "cat_engtype"] = newcol
first(addedcat, 5)
# Out:
# 5×27 DataFrame
#  Row │ symboling  normalized-losses  make      fuel-type  aspiration  num-of-d ⋯
#      │ Int64      Int64              String15  String7    String7     String7  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         2                164  audi      gas        std         four     ⋯
#    2 │         2                164  audi      gas        std         four
#    3 │         1                158  audi      gas        std         four
#    4 │         1                158  audi      gas        turbo       four
#    5 │         2                192  bmw       gas        std         two      ⋯
#                                                               22 columns omitted

# %%
@df addedcat StatsPlots.violin(string.(:cat_engtype), :price)
@df addedcat StatsPlots.boxplot!(string.(:cat_engtype), :price)

# %% [markdown]
# There are certainly some differences in price depending on the engine type.

# %%
combine(grp_fsys, :price => mean, :price => std, :price => extrema)
# Out:
# 5×4 DataFrame
#  Row │ fuel-system  price_mean  price_std  price_extrema
#      │ String7      Float64     Float64    Tuple…
# ─────┼───────────────────────────────────────────────────
#    1 │ mpfi           15101.3    5243.18   (8195, 32250)
#    2 │ 2bbl            7462.87   1439.65   (5118, 10595)
#    3 │ 1bbl            7504.11   1404.09   (5399, 10295)
#    4 │ idi            12650.1    8585.29   (7775, 31600)
#    5 │ spdi            8308.33    851.235  (7689, 9279)

# %%
using CategoricalArrays
newcol = categorical(df[:, "fuel-system"])

addedcat =  df[:, :]
addedcat[:, "cat_fsystem"] = newcol
first(addedcat, 5)
# Out:
# 5×27 DataFrame
#  Row │ symboling  normalized-losses  make      fuel-type  aspiration  num-of-d ⋯
#      │ Int64      Int64              String15  String7    String7     String7  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         2                164  audi      gas        std         four     ⋯
#    2 │         2                164  audi      gas        std         four
#    3 │         1                158  audi      gas        std         four
#    4 │         1                158  audi      gas        turbo       four
#    5 │         2                192  bmw       gas        std         two      ⋯
#                                                               22 columns omitted
# WARNING: both CairoMakie and StatsPlots export "violin!"; uses of it in module Main must be qualified
# WARNING: both CairoMakie and StatsPlots export "boxplot"; uses of it in module Main must be qualified
# WARNING: both CairoMakie and StatsPlots export "boxplot!"; uses of it in module Main must be qualified

# %%
@df addedcat StatsPlots.violin(string.(:cat_fsystem), :price)
@df addedcat StatsPlots.boxplot!(string.(:cat_fsystem), :price)

# %% [markdown]
# I'll keep in mind this feature.

# %%
using CategoricalArrays
newcol = categorical(df[:, "num-of-cylinders"])

addedcat =  df[:, :]
addedcat[:, "cat_ncyl"] = newcol
first(addedcat, 5)
# Out:
# 5×27 DataFrame
#  Row │ symboling  normalized-losses  make      fuel-type  aspiration  num-of-d ⋯
#      │ Int64      Int64              String15  String7    String7     String7  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         2                164  audi      gas        std         four     ⋯
#    2 │         2                164  audi      gas        std         four
#    3 │         1                158  audi      gas        std         four
#    4 │         1                158  audi      gas        turbo       four
#    5 │         2                192  bmw       gas        std         two      ⋯
#                                                               22 columns omitted

# %%
@df addedcat StatsPlots.violin(string.(:cat_ncyl), :price)
@df addedcat StatsPlots.boxplot!(string.(:cat_ncyl), :price)

# %% [markdown]
# That's all for now, I've got my categorical features!

# %%
select(df, Not(droppedfeats))
# Out:
# 159×21 DataFrame
#  Row │ symboling  normalized-losses  make        body-style  wheel-base  lengt ⋯
#      │ Int64      Int64              String15    String15    Float64     Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │         2                164  audi        sedan             99.8    176 ⋯
#    2 │         2                164  audi        sedan             99.4    176
#    3 │         1                158  audi        sedan            105.8    192
#    4 │         1                158  audi        sedan            105.8    192
#    5 │         2                192  bmw         sedan            101.2    176 ⋯
#    6 │         0                192  bmw         sedan            101.2    176
#    7 │         0                188  bmw         sedan            101.2    176
#    8 │         0                188  bmw         sedan            101.2    176
#    9 │         2                121  chevrolet   hatchback         88.4    141 ⋯
#   10 │         1                 98  chevrolet   hatchback         94.5    155
#   11 │         0                 81  chevrolet   sedan             94.5    158
#   ⋮  │     ⋮              ⋮              ⋮           ⋮           ⋮          ⋮  ⋱
#  150 │        -1                 74  volvo       wagon            104.3    188
#  151 │        -2                103  volvo       sedan            104.3    188 ⋯
#  152 │        -1                 74  volvo       wagon            104.3    188
#  153 │        -2                103  volvo       sedan            104.3    188
#  154 │        -1                 74  volvo       wagon            104.3    188
#  155 │        -1                 95  volvo       sedan            109.1    188 ⋯
#  156 │        -1                 95  volvo       sedan            109.1    188
#  157 │        -1                 95  volvo       sedan            109.1    188
#  158 │        -1                 95  volvo       sedan            109.1    188
#  159 │        -1                 95  volvo       sedan            109.1    188 ⋯
#                                                  16 columns and 138 rows omitted

# %%
CSV.write("relevant_categories.csv", select(df, Not(droppedfeats)))
# Out:
# "relevant_categories.csv"
